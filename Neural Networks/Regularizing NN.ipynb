# %% [markdown]
# ## Regularization for Neural Networks
#
# 1. Explain how the three deep learning regularization techniques work
#     * L1/L2 regularization
#     * Dropout
#     * Early stopping
# 2. Implement these techniques in Keras

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

import pandas as pd
import numpy as np

# %% [markdown]
# ## Load the data

# %%
data = pd.read_csv('./data/cell_phone_churn.csv')
data.head()
# Out:
#   state  account_length  area_code intl_plan vmail_plan  vmail_message  \
# 0    KS             128        415        no        yes             25
# 1    OH             107        415        no        yes             26
# 2    NJ             137        415        no         no              0
# 3    OH              84        408       yes         no              0
# 4    OK              75        415       yes         no              0
#
#    day_mins  day_calls  day_charge  eve_mins  eve_calls  eve_charge  \
# 0     265.1        110       45.07     197.4         99       16.78
# 1     161.6        123       27.47     195.5        103       16.62
# 2     243.4        114       41.38     121.2        110       10.30
# 3     299.4         71       50.90      61.9         88        5.26
# 4     166.7        113       28.34     148.3        122       12.61
#
#    night_mins  night_calls  night_charge  intl_mins  intl_calls  intl_charge  \
# 0       244.7           91         11.01       10.0           3         2.70
# 1       254.4          103         11.45       13.7           3         3.70
# 2       162.6          104          7.32       12.2           5         3.29
# 3       196.9           89          8.86        6.6           7         1.78
# 4       186.9          121          8.41       10.1           3         2.73
#
#    custserv_calls  churn
# 0               1  False
# 1               1  False
# 2               0  False
# 3               2  False
# 4               3  False

# %%
# Drop state column
# data = data.drop('state', axis=1)
# data = data.drop('area_code', axis=1)
# data.drop(columns = ['state', 'area_code'], inplace = True)

# One-hot encode state & area columns
data = pd.get_dummies(data, columns = ['state', 'area_code'], drop_first = True)

# Binarize intil_plan and vmail_plan columns
# Many ways to binarize:
data['intl_plan'] = data['intl_plan'].map(lambda x: 1 if x=='yes' else 0)
data['vmail_plan'] = data['vmail_plan'].map(lambda x: 1 if x=='yes' else 0)

# data['intl_plan'] = data['intl_plan'].map({'yes': 1, 'no': 0})
# data['intl_plan'] = (data['intl_plan'] == 'yes').astype('int')
# data['intl_plan'] = (data['intl_plan'] == 'yes') * 1
# data['intl_plan'] = np.where(data['intl_plan'] == 'yes', 1, 0)

# %%
# Split into X and y
X = data.drop('churn', axis=1)
y = data['churn'].astype('int')

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y)

# Scale data
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
1 - y.mean()
# Out:
# 0.8550855085508551

# %% [markdown]
# ## Build a simple neural net to model churn
#
# Let's build this:
#
# - a dense network,
# - one input layer,
# - one hidden layer
#   - slightly smaller than input layer
#   - ReLU activation
# - single node output (for binary classification)

# %% [markdown]
# What activation function will we use for our output layer here?
#
# - Sigmoid activation, since we are doing binary classification.

# %% [markdown]
# > **Fun fact**: If we dropped the hidden layer, this model would just be logistic regression!  Can you prove that to yourself?

# %%
n_input = X_train.shape[1]
n_input
# Out:
# 69

# %%
model = Sequential()

# this is the input layer
model.add(Dense(69, input_dim=n_input, activation='relu'))

# this is the hidden layer, smaller than input, use relu activation
model.add(Dense(20, activation='relu'))

# this is output layer, use sigmoid
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc']) # loss = 'bce'

# %% [markdown]
# ### Create the history of the Neural net fitting, then plot on the graph

# %%
history = model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=None,
    verbose=2
)
# Out:
# Epoch 1/100
# 79/79 - 1s - loss: 0.4174 - acc: 0.8539 - val_loss: 0.3810 - val_acc: 0.8573 - 605ms/epoch - 8ms/step
# Epoch 2/100
# 79/79 - 0s - loss: 0.3428 - acc: 0.8583 - val_loss: 0.3539 - val_acc: 0.8549 - 119ms/epoch - 2ms/step
# Epoch 3/100
# 79/79 - 0s - loss: 0.3084 - acc: 0.8735 - val_loss: 0.3459 - val_acc: 0.8585 - 116ms/epoch - 1ms/step
# Epoch 4/100
# 79/79 - 0s - loss: 0.2854 - acc: 0.8792 - val_loss: 0.3433 - val_acc: 0.8573 - 123ms/epoch - 2ms/step
# Epoch 5/100
# 79/79 - 0s - loss: 0.2648 - acc: 0.8896 - val_loss: 0.3289 - val_acc: 0.8717 - 121ms/epoch - 2ms/step
# Epoch 6/100
# 79/79 - 0s - loss: 0.2435 - acc: 0.9072 - val_loss: 0.3179 - val_acc: 0.8729 - 119ms/epoch - 2ms/step
# Epoch 7/100
# 79/79 - 0s - loss: 0.2235 - acc: 0.9136 - val_loss: 0.3031 - val_acc: 0.8777 - 120ms/epoch - 2ms/step
# Epoch 8/100
# 79/79 - 0s - loss: 0.2037 - acc: 0.9256 - val_loss: 0.2946 - val_acc: 0.8885 - 117ms/epoch - 1ms/step
# Epoch 9/100
# 79/79 - 0s - loss: 0.1866 - acc: 0.9348 - val_loss: 0.2914 - val_acc: 0.8921 - 114ms/epoch - 1ms/step
# Epoch 10/100
# 79/79 - 0s - loss: 0.1713 - acc: 0.9440 - val_loss: 0.2877 - val_acc: 0.8993 - 110ms/epoch - 1ms/step
# Epoch 11/100
# 79/79 - 0s - loss: 0.1586 - acc: 0.9508 - val_loss: 0.2884 - val_acc: 0.8933 - 113ms/epoch - 1ms/step
# Epoch 12/100
# 79/79 - 0s - loss: 0.1460 - acc: 0.9596 - val_loss: 0.2932 - val_acc: 0.8921 - 103ms/epoch - 1ms/step
# Epoch 13/100
# 79/79 - 0s - loss: 0.1359 - acc: 0.9628 - val_loss: 0.2927 - val_acc: 0.8969 - 102ms/epoch - 1ms/step
# Epoch 14/100
# 79/79 - 0s - loss: 0.1254 - acc: 0.9656 - val_loss: 0.2903 - val_acc: 0.8981 - 103ms/epoch - 1ms/step
# Epoch 15/100
# 79/79 - 0s - loss: 0.1160 - acc: 0.9652 - val_loss: 0.3080 - val_acc: 0.8945 - 113ms/epoch - 1ms/step
# Epoch 16/100
# 79/79 - 0s - loss: 0.1081 - acc: 0.9708 - val_loss: 0.3094 - val_acc: 0.8933 - 115ms/epoch - 1ms/step
# Epoch 17/100
# 79/79 - 0s - loss: 0.0995 - acc: 0.9768 - val_loss: 0.3128 - val_acc: 0.9005 - 116ms/epoch - 1ms/step
# Epoch 18/100
# 79/79 - 0s - loss: 0.0939 - acc: 0.9776 - val_loss: 0.3151 - val_acc: 0.8897 - 118ms/epoch - 1ms/step
# Epoch 19/100
# 79/79 - 0s - loss: 0.0869 - acc: 0.9776 - val_loss: 0.3327 - val_acc: 0.8945 - 115ms/epoch - 1ms/step
# Epoch 20/100
# 79/79 - 0s - loss: 0.0785 - acc: 0.9804 - val_loss: 0.3307 - val_acc: 0.8921 - 120ms/epoch - 2ms/step
# Epoch 21/100
# 79/79 - 0s - loss: 0.0767 - acc: 0.9800 - val_loss: 0.3394 - val_acc: 0.8885 - 120ms/epoch - 2ms/step
# Epoch 22/100
# 79/79 - 0s - loss: 0.0655 - acc: 0.9856 - val_loss: 0.3430 - val_acc: 0.8861 - 127ms/epoch - 2ms/step
# Epoch 23/100
# 79/79 - 0s - loss: 0.0583 - acc: 0.9884 - val_loss: 0.3598 - val_acc: 0.8897 - 113ms/epoch - 1ms/step
# Epoch 24/100
# 79/79 - 0s - loss: 0.0537 - acc: 0.9884 - val_loss: 0.3608 - val_acc: 0.8873 - 108ms/epoch - 1ms/step
# Epoch 25/100
# 79/79 - 0s - loss: 0.0487 - acc: 0.9892 - val_loss: 0.3656 - val_acc: 0.8885 - 110ms/epoch - 1ms/step
# Epoch 26/100
# 79/79 - 0s - loss: 0.0453 - acc: 0.9904 - val_loss: 0.3812 - val_acc: 0.8825 - 112ms/epoch - 1ms/step
# Epoch 27/100
# 79/79 - 0s - loss: 0.0412 - acc: 0.9908 - val_loss: 0.4021 - val_acc: 0.8873 - 125ms/epoch - 2ms/step
# Epoch 28/100
# 79/79 - 0s - loss: 0.0380 - acc: 0.9924 - val_loss: 0.4185 - val_acc: 0.8837 - 118ms/epoch - 1ms/step
# Epoch 29/100
# 79/79 - 0s - loss: 0.0352 - acc: 0.9924 - val_loss: 0.4201 - val_acc: 0.8861 - 121ms/epoch - 2ms/step
# Epoch 30/100
# 79/79 - 0s - loss: 0.0306 - acc: 0.9932 - val_loss: 0.4260 - val_acc: 0.8861 - 120ms/epoch - 2ms/step
# Epoch 31/100
# 79/79 - 0s - loss: 0.0278 - acc: 0.9952 - val_loss: 0.4421 - val_acc: 0.8873 - 129ms/epoch - 2ms/step
# Epoch 32/100
# 79/79 - 0s - loss: 0.0248 - acc: 0.9964 - val_loss: 0.4550 - val_acc: 0.8849 - 120ms/epoch - 2ms/step
# Epoch 33/100
# 79/79 - 0s - loss: 0.0225 - acc: 0.9956 - val_loss: 0.4563 - val_acc: 0.8849 - 122ms/epoch - 2ms/step
# Epoch 34/100
# 79/79 - 0s - loss: 0.0206 - acc: 0.9964 - val_loss: 0.4574 - val_acc: 0.8825 - 122ms/epoch - 2ms/step
# Epoch 35/100
# 79/79 - 0s - loss: 0.0187 - acc: 0.9972 - val_loss: 0.4758 - val_acc: 0.8849 - 133ms/epoch - 2ms/step
# Epoch 36/100
# 79/79 - 0s - loss: 0.0172 - acc: 0.9976 - val_loss: 0.4739 - val_acc: 0.8789 - 125ms/epoch - 2ms/step
# Epoch 37/100
# 79/79 - 0s - loss: 0.0147 - acc: 0.9992 - val_loss: 0.5002 - val_acc: 0.8825 - 128ms/epoch - 2ms/step
# Epoch 38/100
# 79/79 - 0s - loss: 0.0148 - acc: 0.9976 - val_loss: 0.5020 - val_acc: 0.8861 - 133ms/epoch - 2ms/step
# Epoch 39/100
# 79/79 - 0s - loss: 0.0135 - acc: 0.9988 - val_loss: 0.5184 - val_acc: 0.8825 - 123ms/epoch - 2ms/step
# Epoch 40/100
# 79/79 - 0s - loss: 0.0120 - acc: 0.9988 - val_loss: 0.5334 - val_acc: 0.8837 - 125ms/epoch - 2ms/step
# Epoch 41/100
# 79/79 - 0s - loss: 0.0113 - acc: 0.9992 - val_loss: 0.5438 - val_acc: 0.8837 - 124ms/epoch - 2ms/step
# Epoch 42/100
# 79/79 - 0s - loss: 0.0095 - acc: 0.9988 - val_loss: 0.5471 - val_acc: 0.8849 - 126ms/epoch - 2ms/step
# Epoch 43/100
# 79/79 - 0s - loss: 0.0088 - acc: 0.9996 - val_loss: 0.5516 - val_acc: 0.8789 - 120ms/epoch - 2ms/step
# Epoch 44/100
# 79/79 - 0s - loss: 0.0087 - acc: 0.9988 - val_loss: 0.5644 - val_acc: 0.8801 - 113ms/epoch - 1ms/step
# Epoch 45/100
# 79/79 - 0s - loss: 0.0067 - acc: 1.0000 - val_loss: 0.5983 - val_acc: 0.8825 - 125ms/epoch - 2ms/step
# Epoch 46/100
# 79/79 - 0s - loss: 0.0064 - acc: 1.0000 - val_loss: 0.5718 - val_acc: 0.8813 - 120ms/epoch - 2ms/step
# Epoch 47/100
# 79/79 - 0s - loss: 0.0055 - acc: 1.0000 - val_loss: 0.5967 - val_acc: 0.8837 - 120ms/epoch - 2ms/step
# Epoch 48/100
# 79/79 - 0s - loss: 0.0051 - acc: 1.0000 - val_loss: 0.6195 - val_acc: 0.8801 - 131ms/epoch - 2ms/step
# Epoch 49/100
# 79/79 - 0s - loss: 0.0065 - acc: 0.9992 - val_loss: 0.6256 - val_acc: 0.8837 - 120ms/epoch - 2ms/step
# Epoch 50/100
# 79/79 - 0s - loss: 0.0049 - acc: 0.9996 - val_loss: 0.6181 - val_acc: 0.8813 - 136ms/epoch - 2ms/step
# Epoch 51/100
# 79/79 - 0s - loss: 0.0041 - acc: 1.0000 - val_loss: 0.6307 - val_acc: 0.8813 - 121ms/epoch - 2ms/step
# Epoch 52/100
# 79/79 - 0s - loss: 0.0037 - acc: 1.0000 - val_loss: 0.6345 - val_acc: 0.8801 - 120ms/epoch - 2ms/step
# Epoch 53/100
# 79/79 - 0s - loss: 0.0035 - acc: 1.0000 - val_loss: 0.6503 - val_acc: 0.8813 - 120ms/epoch - 2ms/step
# Epoch 54/100
# 79/79 - 0s - loss: 0.0031 - acc: 1.0000 - val_loss: 0.6555 - val_acc: 0.8789 - 128ms/epoch - 2ms/step
# Epoch 55/100
# 79/79 - 0s - loss: 0.0029 - acc: 1.0000 - val_loss: 0.6741 - val_acc: 0.8813 - 120ms/epoch - 2ms/step
# Epoch 56/100
# 79/79 - 0s - loss: 0.0027 - acc: 1.0000 - val_loss: 0.6649 - val_acc: 0.8813 - 121ms/epoch - 2ms/step
# Epoch 57/100
# 79/79 - 0s - loss: 0.0027 - acc: 1.0000 - val_loss: 0.6925 - val_acc: 0.8825 - 136ms/epoch - 2ms/step
# Epoch 58/100
# 79/79 - 0s - loss: 0.0023 - acc: 1.0000 - val_loss: 0.6833 - val_acc: 0.8789 - 136ms/epoch - 2ms/step
# Epoch 59/100
# 79/79 - 0s - loss: 0.0022 - acc: 1.0000 - val_loss: 0.6938 - val_acc: 0.8801 - 136ms/epoch - 2ms/step
# Epoch 60/100
# 79/79 - 0s - loss: 0.0020 - acc: 1.0000 - val_loss: 0.7108 - val_acc: 0.8813 - 120ms/epoch - 2ms/step
# Epoch 61/100
# 79/79 - 0s - loss: 0.0019 - acc: 1.0000 - val_loss: 0.7142 - val_acc: 0.8801 - 128ms/epoch - 2ms/step
# Epoch 62/100
# 79/79 - 0s - loss: 0.0017 - acc: 1.0000 - val_loss: 0.7134 - val_acc: 0.8777 - 136ms/epoch - 2ms/step
# Epoch 63/100
# 79/79 - 0s - loss: 0.0031 - acc: 0.9992 - val_loss: 0.7525 - val_acc: 0.8861 - 136ms/epoch - 2ms/step
# Epoch 64/100
# 79/79 - 0s - loss: 0.0029 - acc: 0.9996 - val_loss: 0.7344 - val_acc: 0.8801 - 128ms/epoch - 2ms/step
# Epoch 65/100
# 79/79 - 0s - loss: 0.0021 - acc: 1.0000 - val_loss: 0.7398 - val_acc: 0.8837 - 136ms/epoch - 2ms/step
# Epoch 66/100
# 79/79 - 0s - loss: 0.0014 - acc: 1.0000 - val_loss: 0.7446 - val_acc: 0.8789 - 128ms/epoch - 2ms/step
# Epoch 67/100
# 79/79 - 0s - loss: 0.0013 - acc: 1.0000 - val_loss: 0.7546 - val_acc: 0.8813 - 128ms/epoch - 2ms/step
# Epoch 68/100
# 79/79 - 0s - loss: 0.0012 - acc: 1.0000 - val_loss: 0.7588 - val_acc: 0.8789 - 136ms/epoch - 2ms/step
# Epoch 69/100
# 79/79 - 0s - loss: 0.0011 - acc: 1.0000 - val_loss: 0.7752 - val_acc: 0.8837 - 136ms/epoch - 2ms/step
# Epoch 70/100
# 79/79 - 0s - loss: 9.6706e-04 - acc: 1.0000 - val_loss: 0.7772 - val_acc: 0.8789 - 136ms/epoch - 2ms/step
# Epoch 71/100
# 79/79 - 0s - loss: 0.0060 - acc: 0.9984 - val_loss: 0.8368 - val_acc: 0.8705 - 136ms/epoch - 2ms/step
# Epoch 72/100
# 79/79 - 0s - loss: 0.0107 - acc: 0.9968 - val_loss: 0.7807 - val_acc: 0.8705 - 128ms/epoch - 2ms/step
# Epoch 73/100
# 79/79 - 0s - loss: 0.0252 - acc: 0.9904 - val_loss: 0.8251 - val_acc: 0.8801 - 120ms/epoch - 2ms/step
# Epoch 74/100
# 79/79 - 0s - loss: 0.0172 - acc: 0.9952 - val_loss: 0.7688 - val_acc: 0.8849 - 126ms/epoch - 2ms/step
# Epoch 75/100
# 79/79 - 0s - loss: 0.0054 - acc: 0.9992 - val_loss: 0.7890 - val_acc: 0.8897 - 120ms/epoch - 2ms/step
# Epoch 76/100
# 79/79 - 0s - loss: 0.0044 - acc: 0.9988 - val_loss: 0.7654 - val_acc: 0.8801 - 113ms/epoch - 1ms/step
# Epoch 77/100
# 79/79 - 0s - loss: 0.0017 - acc: 1.0000 - val_loss: 0.7832 - val_acc: 0.8885 - 116ms/epoch - 1ms/step
# Epoch 78/100
# 79/79 - 0s - loss: 0.0012 - acc: 1.0000 - val_loss: 0.7801 - val_acc: 0.8885 - 130ms/epoch - 2ms/step
# Epoch 79/100
# 79/79 - 0s - loss: 9.0655e-04 - acc: 1.0000 - val_loss: 0.7921 - val_acc: 0.8885 - 128ms/epoch - 2ms/step
# Epoch 80/100
# 79/79 - 0s - loss: 8.2555e-04 - acc: 1.0000 - val_loss: 0.7994 - val_acc: 0.8897 - 115ms/epoch - 1ms/step
# Epoch 81/100
# 79/79 - 0s - loss: 7.7205e-04 - acc: 1.0000 - val_loss: 0.8045 - val_acc: 0.8897 - 120ms/epoch - 2ms/step
# Epoch 82/100
# 79/79 - 0s - loss: 7.0636e-04 - acc: 1.0000 - val_loss: 0.8085 - val_acc: 0.8873 - 118ms/epoch - 1ms/step
# Epoch 83/100
# 79/79 - 0s - loss: 6.6497e-04 - acc: 1.0000 - val_loss: 0.8145 - val_acc: 0.8873 - 128ms/epoch - 2ms/step
# Epoch 84/100
# 79/79 - 0s - loss: 6.2469e-04 - acc: 1.0000 - val_loss: 0.8185 - val_acc: 0.8885 - 128ms/epoch - 2ms/step
# Epoch 85/100
# 79/79 - 0s - loss: 5.9087e-04 - acc: 1.0000 - val_loss: 0.8230 - val_acc: 0.8885 - 128ms/epoch - 2ms/step
# Epoch 86/100
# 79/79 - 0s - loss: 5.5854e-04 - acc: 1.0000 - val_loss: 0.8290 - val_acc: 0.8873 - 128ms/epoch - 2ms/step
# Epoch 87/100
# 79/79 - 0s - loss: 5.3265e-04 - acc: 1.0000 - val_loss: 0.8333 - val_acc: 0.8873 - 120ms/epoch - 2ms/step
# Epoch 88/100
# 79/79 - 0s - loss: 5.0675e-04 - acc: 1.0000 - val_loss: 0.8380 - val_acc: 0.8873 - 121ms/epoch - 2ms/step
# Epoch 89/100
# 79/79 - 0s - loss: 4.8904e-04 - acc: 1.0000 - val_loss: 0.8410 - val_acc: 0.8873 - 120ms/epoch - 2ms/step
# Epoch 90/100
# 79/79 - 0s - loss: 4.5910e-04 - acc: 1.0000 - val_loss: 0.8458 - val_acc: 0.8861 - 104ms/epoch - 1ms/step
# Epoch 91/100
# 79/79 - 0s - loss: 4.4089e-04 - acc: 1.0000 - val_loss: 0.8499 - val_acc: 0.8861 - 110ms/epoch - 1ms/step
# Epoch 92/100
# 79/79 - 0s - loss: 4.2058e-04 - acc: 1.0000 - val_loss: 0.8483 - val_acc: 0.8861 - 130ms/epoch - 2ms/step
# Epoch 93/100
# 79/79 - 0s - loss: 4.0571e-04 - acc: 1.0000 - val_loss: 0.8564 - val_acc: 0.8849 - 129ms/epoch - 2ms/step
# Epoch 94/100
# 79/79 - 0s - loss: 3.8679e-04 - acc: 1.0000 - val_loss: 0.8578 - val_acc: 0.8837 - 128ms/epoch - 2ms/step
# Epoch 95/100
# 79/79 - 0s - loss: 3.7469e-04 - acc: 1.0000 - val_loss: 0.8682 - val_acc: 0.8849 - 128ms/epoch - 2ms/step
# Epoch 96/100
# 79/79 - 0s - loss: 3.5594e-04 - acc: 1.0000 - val_loss: 0.8651 - val_acc: 0.8861 - 128ms/epoch - 2ms/step
# Epoch 97/100
# 79/79 - 0s - loss: 3.4121e-04 - acc: 1.0000 - val_loss: 0.8693 - val_acc: 0.8849 - 129ms/epoch - 2ms/step
# Epoch 98/100
# 79/79 - 0s - loss: 3.2648e-04 - acc: 1.0000 - val_loss: 0.8795 - val_acc: 0.8825 - 136ms/epoch - 2ms/step
# Epoch 99/100
# 79/79 - 0s - loss: 3.1339e-04 - acc: 1.0000 - val_loss: 0.8836 - val_acc: 0.8837 - 128ms/epoch - 2ms/step
# Epoch 100/100
# 79/79 - 0s - loss: 2.9851e-04 - acc: 1.0000 - val_loss: 0.8842 - val_acc: 0.8837 - 120ms/epoch - 2ms/step

# %%
train_loss = history.history['loss']
test_loss = history.history['val_loss']

plt.figure(figsize=(12, 8))
plt.plot(train_loss, label='Training loss', color='navy')
plt.plot(test_loss, label='Testing loss', color='orange')
plt.legend();

# %%
history.history['acc'][-1], history.history['val_acc'][-1]
# Out:
# (1.0, 0.8836930394172668)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 69)                4830
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                1400
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 6,251
# Trainable params: 6,251
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ![](../assets/overkill.jpg)

# %% [markdown]
# ## Regularization Method 1: $\mathcal{l}_1$ and $\mathcal{l}_2$
# ---
#
# ## Which to pick: $\mathcal{l}_1$ or $\mathcal{l}_2$?
# Recall the key difference: $\mathcal{l}_1$ penalties perform _selection_. That is, they often zero out parameters when they're small enough. While this sounds appealing, $\mathcal{l}_2$ is used almost exclusively. It's done so often, that deep learning practitions give it a special name: **weight decay**.

# %%
# from tensorflow.keras import regularizers
from tensorflow.keras.regularizers import l2

model_l2 = Sequential()

n_input = X_train.shape[1]

model_l2.add(Dense(
    69,
    input_dim=n_input,
    activation='relu',
    kernel_regularizer=l2(0.001)
))

model_l2.add(Dense(
    20,
    activation='relu',
    kernel_regularizer=l2(0.001)
))

model_l2.add(Dense(
    1,
    activation='sigmoid',
    kernel_regularizer=l2(0.001)
))

model_l2.compile(
    loss='bce',
    optimizer='adam',
    metrics=['acc']
)

history_l2 = model_l2.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=None
)
# Out:
# Epoch 1/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.5422 - acc: 0.8463 - val_loss: 0.4771 - val_acc: 0.8525
# Epoch 2/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0
plt.plot(test_loss, label='Testing loss', color='skyblue')
plt.plot(train_loss_l2, label='L2 Training loss', color='darkred')
plt.plot(test_loss_l2, label='L2 Testing loss', color='pink')
plt.legend();

# %%
history_l2.history['acc'][-1], history_l2.history['val_acc'][-1]
# Out:
# (0.9971988797187805, 0.8944844007492065)

# %% [markdown]
# <a id='dropout'></a>
# ## Regularization Method 2: Dropout
# ---
# There's another method of regularizing our terms that is specifically designed for neural networks, called **dropout regularization.**

# %% [markdown]
# Let's say we've constructed a neural network. We've decided on the number of layers we want and the number of nodes in each layer. (We might say that we've decided on the **topology** or **structure** of our network.)
#
# However, a densely connected network like this will almost certainly overfit. Our network is learning a parameter for every single connection.
#
# In dropout regularization, we randomly **drop** units (nodes) in our neural network ***during our training phase only***. We assign a probability of each node disappearing. Then, we essentially perform a coinflip for every node to turn that node "on" or "off."
#
# Let's go through an example to illustrate this: For simplicity, we'll say we've assigned a 0.5 probability of keeping to every node in the network above. Then, for every node, we flip a coin, and if the coin lands on heads, the node remains, if it lands on tails, the node disappears. After we've done this for every node, we're left with a new network that looks something like this:
#
# ![](../assets/after_dropout.jpeg)
#
# <!--
# Image sources: https://pgaleone.eu/deep-learning/regularization/2017/01/10/anaysis-of-dropout/
# Also, it seems, this site: http://cs231n.github.io/neural-networks-2/
# -->
#
# Let's explicitly lay out the general workflow you would follow:
#
# 1. Specify the topology of your neural network.
# 2. Initialize your weights and biases.
# 3. Specify the "keeping probabilities" for every node. (Generally, we'll assign the same probability to all nodes in each layer and usually the same probability to all hidden layers.)
# 4. Perform a "coin flip" for each node and drop out the chosen nodes.
# 5. Run through one epoch of training.
# 6. Repeat steps 4 and 5 for each epoch of training.

# %% [markdown]
# ![](https://cdn.analyticsvidhya.com/wp-content/uploads/2018/04/1IrdJ5PghD9YoOyVAQ73MJw.gif)

# %% [markdown]
# <details><summary>If I drop out a node during one of my epochs, does it disappear from my final network?</summary>
#
# - No!
# </details>

# %% [markdown]
# #### So, what does this do?
# <!-- <br/> -->
# The intuition behind dropout is that, since each node has a probability of disappearing at any time, the neural network is disincentivized from allocating too much power to any one weight. It has a similar effect as imposing an L2 penalty: the magnitude of our weights shrinks.

# %% [markdown]
# <details><summary>What might be some potential problems with doing this?</summary>
#
# - expected values of nodes changes
# - induces bias
# </details>

# %% [markdown]
# So we've now run through every epoch of our training phase and we're ready to apply our neural network to our validation or testing data.
#
# <details><summary>Are we going to apply dropout to this data as well?</summary>
#
# - No!
# </details>

# %% [markdown]
# #### Best practices:
#
# - Don't set any keeping probabilities for layers you where you don't want to drop any nodes.
#
# <details><summary>What might be examples of these layers?</summary>
#
# - Input layers
# - Output layers
# </details>

# %% [markdown]
# - You'll generally want to specify a single keeping probability and all the layers on which you want to apply dropout, instead of specifying different keeping probabilities for each layer.

# %%
from tensorflow.keras.layers import Dropout

model_dropout = Sequential()

n_input = X_train.shape[1]
n_hidden = n_input

model_dropout.add(Dense(n_hidden, input_dim=n_input, activation='relu'))
model_dropout.add(Dropout(0.2)) # refers to nodes in the first hidden layer
model_dropout.add(Dense(20, activation='relu'))
model_dropout.add(Dropout(0.2))
model_dropout.add(Dense(1, activation='sigmoid'))

model_dropout.compile(loss='bce', optimizer='adam', metrics=['acc'])

history_dropout = model_dropout.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test), 
    epochs=100,
    batch_size=None
)
# Out:
# Epoch 1/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.4694 - acc: 0.8231 - val_loss: 0.3908 - val_acc: 0.8525
# Epoch 2/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3936 - acc: 0.8515 - val_loss: 0.3607 - val_acc: 0.8525
# Epoch 3/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3608 - acc: 0.8611 - val_loss: 0.3475 - val_acc: 0.8537
# Epoch 4/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3365 - acc: 0.8675 - val_loss: 0.3368 - val_acc: 0.8645
# Epoch 5/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3204 - acc: 0.8711 - val_loss: 0.3312 - val_acc: 0.8669
# Epoch 6/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3112 - acc: 0.8780 - val_loss: 0.3240 - val_acc: 0.8693
# Epoch 7/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2992 - acc: 0.8880 - val_loss: 0.3181 - val_acc: 0.8741
# Epoch 8/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2828 - acc: 0.8876 - val_loss: 0.3153 - val_acc: 0.8753
# Epoch 9/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2726 - acc: 0.8984 - val_loss: 0.3050 - val_acc: 0.8753
# Epoch 10/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2629 - acc: 0.8984 - val_loss: 0.2978 - val_acc: 0.8765
# Epoch 11/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2538 - acc: 0.9024 - val_loss: 0.2898 - val_acc: 0.8813
# Epoch 12/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2467 - acc: 0.9020 - val_loss: 0.2899 - val_acc: 0.8789
# Epoch 13/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2411 - acc: 0.9072 - val_loss: 0.2858 - val_acc: 0.8825
# Epoch 14/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2332 - acc: 0.9092 - val_loss: 0.2803 - val_acc: 0.8849
# Epoch 15/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2256 - acc: 0.9216 - val_loss: 0.2760 - val_acc: 0.8873
# Epoch 16/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2200 - acc: 0.9172 - val_loss: 0.2756 - val_acc: 0.8885
# Epoch 17/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2138 - acc: 0.9204 - val_loss: 0.2779 - val_acc: 0.8945
# Epoch 18/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2135 - acc: 0.9244 - val_loss: 0.2740 - val_acc: 0.8849
# Epoch 19/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2044 - acc: 0.9272 - val_loss: 0.2708 - val_acc: 0.9005
# Epoch 20/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1957 - acc: 0.9220 - val_loss: 0.2717 - val_acc: 0.8957
# Epoch 21/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1899 - acc: 0.9268 - val_loss: 0.2761 - val_acc: 0.8957
# Epoch 22/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1928 - acc: 0.9272 - val_loss: 0.2757 - val_acc: 0.9029
# Epoch 23/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1768 - acc: 0.9392 - val_loss: 0.2810 - val_acc: 0.9017
# Epoch 24/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1781 - acc: 0.9336 - val_loss: 0.2826 - val_acc: 0.8981
# Epoch 25/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1761 - acc: 0.9324 - val_loss: 0.2723 - val_acc: 0.9017
# Epoch 26/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1685 - acc: 0.9400 - val_loss: 0.2758 - val_acc: 0.9041
# Epoch 27/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1629 - acc: 0.9416 - val_loss: 0.2794 - val_acc: 0.9017
# Epoch 28/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.
100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0636 - acc: 0.9744 - val_loss: 0.4458 - val_acc: 0.9005
# Epoch 91/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0536 - acc: 0.9760 - val_loss: 0.4645 - val_acc: 0.8933
# Epoch 92/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0626 - acc: 0.9756 - val_loss: 0.4367 - val_acc: 0.8993
# Epoch 93/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0664 - acc: 0.9748 - val_loss: 0.4442 - val_acc: 0.8993
# Epoch 94/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0471 - acc: 0.9796 - val_loss: 0.4875 - val_acc: 0.8933
# Epoch 95/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0506 - acc: 0.9808 - val_loss: 0.4731 - val_acc: 0.8909
# Epoch 96/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0525 - acc: 0.9812 - val_loss: 0.4951 - val_acc: 0.8897
# Epoch 97/100
# 79/79 [==============================] - 0s 995us/step - loss: 0.0520 - acc: 0.9788 - val_loss: 0.4717 - val_acc: 0.8885
# Epoch 98/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0614 - acc: 0.9776 - val_loss: 0.4847 - val_acc: 0.8873
# Epoch 99/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0719 - acc: 0.9764 - val_loss: 0.4876 - val_acc: 0.8909
# Epoch 100/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.0603 - acc: 0.9752 - val_loss: 0.4870 - val_acc: 0.8933

# %%
train_loss_dropout = history_dropout.history['loss']
test_loss_dropout = history_dropout.history['val_loss']

plt.figure(figsize=(12, 8))
plt.plot(train_loss, label='Training loss', color='navy')
plt.plot(test_loss, label='Testing loss', color='skyblue')
plt.plot(train_loss_dropout, label='Dropout Training loss', color='darkgreen')
plt.plot(test_loss_dropout, label='Dropout Testing loss', color='lightgreen')
plt.legend();

# %%
history_dropout.history['acc'][-1], history_dropout.history['val_acc'][-1]
# Out:
# (0.9751901030540466, 0.8932853937149048)

# %% [markdown]
# ## Keras Resources
# - [Keras Dropout Documentation](https://keras.io/layers/core/#dropout)
#
# ## Tensorflow Resources
# - [Tensorflow documentation](https://www.tensorflow.org/api_docs/python/tf/nn/dropout)
# - [List of examples in Tensorflow](https://programtalk.com/python-examples/tensorflow.nn.dropout/)

# %% [markdown]
# <a id='stopping'></a>
# ## Regularization Method 3: Early Stopping
# ---
# The third method of regularization that we'll discuss today is called early stopping.
# </br>
# If we run though all our epochs of training and plot both our training and validation error, we'll typically see something like this:
#
# ![](../assets/train-val-error-reduced.png)
# *source*: [Prechelt, 1997](http://page.mi.fu-berlin.de/prechelt/Biblio/stop_tricks1997.pdf)

# %% [markdown]
# <details><summary>What is happening in this plot?</summary>
#
# - The Validation error begins to increase after a certain number of epochs!
# </details>

# %% [markdown]
# Early stopping does exactly what its name implies: it stop the training process early. Instead of continuing training through every epoch, once the validation error begins to increase, our algorithm stops because it has (in theory) found the minimum for the validation loss.
#
# This might seem like a simple and robust solution to overfitting, but it can run into problems.
#
# ![](../assets/validation-error-real.png)
#
# There is debate over how often this problem occurs. You can generally plot both the training and validation loss, see if you're getting multiple optima. If you are, there are multiple suggested techniques to combat this problem in the [paper reference above](http://page.mi.fu-berlin.de/prechelt/Biblio/stop_tricks1997.pdf).

# %%
from tensorflow.keras.callbacks import EarlyStopping

model_es = Sequential()

n_input = X_train.shape[1]

model_es.add(Dense(17, input_dim=n_input, activation='relu'))
model_es.add(Dense(10, activation='relu'))
model_es.add(Dense(1, activation='sigmoid'))

model_es.compile(loss='bce', optimizer='adam', metrics=['acc'])

early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=1, mode='auto')

history_es = model_es.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=None,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/100
# 79/79 [==============================] - 0s 2ms/step - loss: 0.4740 - acc: 0.8535 - val_loss: 0.4403 - val_acc: 0.8525
# Epoch 2/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.4073 - acc: 0.8551 - val_loss: 0.4061 - val_acc: 0.8597
# Epoch 3/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3707 - acc: 0.8583 - val_loss: 0.3863 - val_acc: 0.8633
# Epoch 4/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3444 - acc: 0.8655 - val_loss: 0.3733 - val_acc: 0.8645
# Epoch 5/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3263 - acc: 0.8703 - val_loss: 0.3625 - val_acc: 0.8657
# Epoch 6/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3124 - acc: 0.8727 - val_loss: 0.3549 - val_acc: 0.8717
# Epoch 7/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3008 - acc: 0.8776 - val_loss: 0.3490 - val_acc: 0.8657
# Epoch 8/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2917 - acc: 0.8816 - val_loss: 0.3450 - val_acc: 0.8645
# Epoch 9/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2834 - acc: 0.8844 - val_loss: 0.3414 - val_acc: 0.8717
# Epoch 10/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2747 - acc: 0.8884 - val_loss: 0.3375 - val_acc: 0.8705
# Epoch 11/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2665 - acc: 0.8892 - val_loss: 0.3306 - val_acc: 0.8753
# Epoch 12/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2576 - acc: 0.8952 - val_loss: 0.3251 - val_acc: 0.8765
# Epoch 13/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2488 - acc: 0.8988 - val_loss: 0.3177 - val_acc: 0.8765
# Epoch 14/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2398 - acc: 0.9080 - val_loss: 0.3156 - val_acc: 0.8765
# Epoch 15/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2312 - acc: 0.9136 - val_loss: 0.3113 - val_acc: 0.8813
# Epoch 16/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2234 - acc: 0.9172 - val_loss: 0.3070 - val_acc: 0.8801
# Epoch 17/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.2161 - acc: 0.9228 - val_loss: 0.3056 - val_acc: 0.8825
# Epoch 18/100
# 79/79 [==============================] - 0s 996us/step - loss: 0.2084 - acc: 0.9248 - val_loss: 0.3044 - val_acc: 0.8837
# Epoch 19/100
# 79/79 [==============================] - 0s 997us/step - loss: 0.2010 - acc: 0.9292 - val_loss: 0.2995 - val_acc: 0.8837
# Epoch 20/100
# 79/79 [==============================] - 0s 999us/step - loss: 0.1934 - acc: 0.9312 - val_loss: 0.3013 - val_acc: 0.8921
# Epoch 21/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1868 - acc: 0.9328 - val_loss: 0.2975 - val_acc: 0.8897
# Epoch 22/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1812 - acc: 0.9344 - val_loss: 0.2975 - val_acc: 0.8873
# Epoch 23/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1741 - acc: 0.9380 - val_loss: 0.2982 - val_acc: 0.8921
# Epoch 24/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1688 - acc: 0.9400 - val_loss: 0.2981 - val_acc: 0.8921
# Epoch 25/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1621 - acc: 0.9428 - val_loss: 0.2995 - val_acc: 0.8921
# Epoch 26/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1578 - acc: 0.9432 - val_loss: 0.3020 - val_acc: 0.8933
# Epoch 27/100
# 79/79 [==============================] - 0s 1ms/step - loss: 0.1549 - acc: 0.9436 - val_loss: 0.3034 - val_acc: 0.8909
# Epoch 00027: early stopping

# %%
train_loss_es = history_es.history['loss']
test_loss_es = history_es.history['val_loss']
plt.figure(figsize=(12, 8))
plt.plot(train_loss, label='Training loss', color='violet')
plt.plot(test_loss, label='Testing loss', color='lavender')
plt.plot(train_loss_es, label='ES Training loss', color='navy')
plt.plot(test_loss_es, label='ES Testing loss', color='skyblue')
plt.legend();

# %%
history_es.history['acc'][-1], history_es.history['val_acc'][-1]
# Out:
# (0.9435774087905884, 0.8908872604370117)

# %% [markdown]
# ## Keras Resources
# - [Keras EarlyStopping Documentation](https://keras.io/callbacks/#earlystopping)
# - [Keras EarlyStopping Example](http://parneetk.github.io/blog/neural-networks-in-keras/)
#
# ## Tensorflow Resources
# - [Tensorflow.Keras.callbacks.EarlyStopping Documentation](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStopping)

# %% [markdown]
# # Optimization
# ---
# Now we're going to talk about ways to speed up the process of optimization. Surprisingly, local optima are not often problems with neural networks; there's a much larger issue with "plateaus," or areas where the derivative is approximately 0. This makes learning much slower.
#
# ## Quick Fixes:
# 1. **Feature Scaling:** As we've discussed before, feature scaling can speed up the process of gradient descent. Because gradient descent works "geometrically," the scales of our $w$ values have a large impact on how quickly our parameters converge to the true value. Since we're working with many parameters (often 1,000 or more), scaling our features will speed up optimization.
#
# 2. **Mini-batch Gradient Descent:** In `sklearn`, we use `.fit()` to estimate the parameters in our model. We do the same in neural networks, but if we're working with a very large data set (as is common in neural networks), passing data through our network will cause learning to be slow. By specifying a `batch_size` within the `.fit()` method, we can expedite our learning.
#     - `batch_size`: Integer or `None`. Number of samples per gradient update. If unspecified, it will default to 32.
#
# **Note:** Mini batches will usually be a power of 2 (32, 64, 128, 256, 512) due to the fact that computers operate in base 2.
#
# - [Overview of the three types of gradient descent: batch, stochastic, mini-batch](https://machinelearningmastery.com/gentle-introduction-mini-batch-gradient-descent-configure-batch-size/)

# %% [markdown]
# <a id='momentum'></a>
# ## Gradient Descent with Momentum
#
# One problem we notice with mini-batch gradient descent compared to batch gradient descent is that it tends to oscillate more, due to the fact that at each iteration it is being fed less training data than batch gradient descent.
#
# ![](../assets/grad-descent.png)
# ![](../assets/mini-grad-descent.png)
#
# [*source*](http://pengcheng.tech/2017/09/28/gradient-descent-momentum-and-adam/)
#
# Ideally, we'd like to take advantage of the speed and memory efficiency of mini-batch gradient descent, without the oscillations. We can use the idea of **momentum** to help us out here. (Momentum is based on [exponentially weighted moving averages](https://www.compose.com/articles/metrics-maven-calculating-an-exponentially-weighted-moving-average-in-postgresql/), which causes our oscillations to largely cancel each other out.)
#
# Typically, when updating our parameters, we'll follow this formula:
#
# $$W = W -\alpha\frac{\partial \text{loss}}{\partial W}$$
# $$b = b - \alpha\frac{\partial \text{loss}}{\partial b}$$
#
# We're going to modify this formula to this form:
#
# $$W = W -\alpha V_{\partial W}$$
# $$b = b - \alpha V_{\partial b}$$
#
# Where
# $$V_{\partial W} = \beta V_{\partial W - 1} + (1-\beta)\frac{\partial \text{loss}}{\partial W}$$
# and
# $$V_{\partial b} = \beta V_{\partial b - 1} + (1-\beta)\frac{\partial \text{loss}}{\partial b}$$
#
# When implementing gradient descent with momentum, you'll have two hyperparameters, $\alpha$ and $\beta$. From a practical point of view, $\beta$ is typically $0.9$, but you can test out other values if you'd like.
#
# ### ADAM Optimization
#
# The optimization algorithm you'll likely use when implementing your feed-forward neural network is called ADAM (Adaptive Moment Estimation). It is a combination of gradient descent with momentum and another optimization method called RMSProp (Root Mean Square Propagation). For the sake of this lesson, we won't cover how ADAM works, but with gradient descent with momentum as building block, the ADAM optimization is not too far off, as it largely relies on the concept of momentum.

# %% [markdown]
# ### Data Augmentation
#
# One method of minimizing the risk of overfitting is to gather more data. While this is usually very costly, we may sometimes be able to take our existing data to generate substantially more data.
# - Images: Reflect, crop, random rotations or distortions, adjust lighting.
#     - [The Effectiveness of Data Augmentation in Image Classification using Deep Learning](http://cs231n.stanford.edu/reports/2017/pdfs/300.pdf)
# - Non-Images: [SMOTE](https://machinelearningmastery.com/smote-oversampling-for-imbalanced-classification/) (Synthetic Minority Over-Sampling Technique)

# %% [markdown]
# <a id='conclusion'></a>
# # Conclusion
#
# Today, we learned about three different methods of regularizing our neural networks: Regularization, dropout, and early stopping.
#
# ## Machine Learning Workflow
#
# As promised, managing bias and variance takes a lot of our attention. If our bias or variance are high, it's likely that our model isn't performing as well as it could.
#
# A workflow for how you should address this (in the context of neural networks and beyond) is as follows:
#
# - Do we have high bias? (i.e. are we performing poorly on our training set?)
#     - If so:
#         - let's build a more complex model / bigger network!
#         - let's consider a new architecture for our neural network!
#         - let's train longer!
# - Do we have high variance? (i.e. are we performing poorly on our test/holdout set?)
#     - If so:
#         - let's gather more data!
#             - Usually very difficult, but we should use "data augmentation" if we can!
#         - let's build a simpler model / smaller network!
#         - let's consider a new architecture for our neural network!
#         - let's regularize!
#     - Once we're satisfied, return to the bias question and repeat.
#
# **Note:** Before deep learning, most tools for handling high bias or high variance adversely affected the other. However, depending on the amount of data we have and how complex our network is, it's often the case that we can drastically reduce variance with out affecting bias.
#
# We also learned about Mini-batch Gradient Descent and Gradient Descent with Momentum. You will almost always work with mini batches. And when optimizing, you will generally use a method called Adam Optimization that is built on a combination of Gradient Descent with Momentum and another optimization technique called RMSProp.
#
# We also briefly discussed data augmentation as a method for increasing our sample sie.
#
# <a id='references'></a>
# ## References and Resources:
#
# - [DeepLearning.ai](https://www.deeplearning.ai/), Andrew Ng's Coursera course on Deep Learning
#   - The videos from this course are on a [YouTube Channel](https://www.youtube.com/channel/UCcIXc5mJsHVYTZR1maL5l9w/featured)
# <br>
# - [Deep Learning Book](http://www.deeplearningbook.org/), textbook written by Ian Goodfellow, creator of Generative Adversarial Networks (GANs)
